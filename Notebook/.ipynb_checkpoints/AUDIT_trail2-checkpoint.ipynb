# %%
import pandas as pd

df=pd.read_csv('AUDIT_dataset - 1.csv')
df.head(10)
# Out:
#                          Participant ID  \
# 0  008554f0-a4b8-46b2-b96d-41ba129874b8
# 1  3cd46f5b-0fa0-4338-b1ce-9a92c533a87d
# 2  a1f723c4-2c2c-4e0e-9842-2b539f8910ce
# 3  82060640-e700-4e43-9539-1c0d487398cc
# 4  1be7ebab-17cc-4990-a5d7-ae61c121b54f
# 5  84382bd9-b588-476f-9132-6df8e851f2af
# 6  15a30974-8186-4d49-9be9-c09d95d05ff8
# 7  a19d019e-ef7b-4f73-b923-e8a05a5cbb20
# 8  d8d6c4fc-331d-4181-af5f-91c832f61220
# 9  2f3acbdb-f272-4e67-bc61-c3f174c672e6
#
#   How often do you have a drink containing alcohol?  \
# 0                                             Never
# 1                                             Never
# 2                            4 or more times a week
# 3                                 2-4 times a month
# 4                                             Never
# 5                                             Never
# 6                                   Monthly or less
# 7                                 2-4 times a month
# 8                                 2-4 times a month
# 9                                   Monthly or less
#
#   How many standard drinks do you have on a typical drinking day?  \
# 0                                             5 or 6
# 1                                             5 or 6
# 2                                         10 or more
# 3                                             5 or 6
# 4                                             5 or 6
# 5                                         10 or more
# 6                                             5 or 6
# 7                                             7 to 9
# 8                                             3 or 4
# 9                                             3 or 4
#
#   How often do you have six or more drinks on one occasion?  \
# 0                              Daily or almost daily
# 1                                              Never
# 2                                  Less than monthly
# 3                                  Less than monthly
# 4                                              Never
# 5                                              Never
# 6                                            Monthly
# 7                                             Weekly
# 8                                  Less than monthly
# 9                              Daily or almost daily
#
#   How often do you find it hard to stop drinking once started?  \
# 0                                             Weekly
# 1                                            Monthly
# 2                              Daily or almost daily
# 3                              Daily or almost daily
# 4                              Daily or almost daily
# 5                              Daily or almost daily
# 6                              Daily or almost daily
# 7                              Daily or almost daily
# 8                                             Weekly
# 9                                              Never
#
#   How often do you fail to do what is expected due to drinking?  \
# 0                                  Less than monthly
# 1                                              Never
# 2                                  Less than monthly
# 3                                             Weekly
# 4                                             Weekly
# 5                                              Never
# 6                              Daily or almost daily
# 7                                  Less than monthly
# 8                                             Weekly
# 9                              Daily or almost daily
#
#   How often do you need a drink in the morning after heavy drinking?  \
# 0                              Daily or almost daily
# 1                                  Less than monthly
# 2                                             Weekly
# 3                                  Less than monthly
# 4                                  Less than monthly
# 5                                            Monthly
# 6                                             Weekly
# 7                                             Weekly
# 8                                             Weekly
# 9                                            Monthly
#
#   How often do you feel guilt or remorse after drinking?  \
# 0                              Daily or almost daily
# 1                              Daily or almost daily
# 2                                            Monthly
# 3                                            Monthly
# 4                                             Weekly
# 5                              Daily or almost daily
# 6                                  Less than monthly
# 7                                            Monthly
# 8                              Daily or almost daily
# 9                                              Never
#
#   How often do you forget what happened because of drinking?  \
# 0                                             Weekly
# 1                                            Monthly
# 2                                              Never
# 3                              Daily or almost daily
# 4                                             Weekly
# 5                              Daily or almost daily
# 6                                              Never
# 7                                             Weekly
# 8                                              Never
# 9                                              Never
#
#   Have you or someone else been injured due to your drinking?  \
# 0                                                 No
# 1                                                 No
# 2                          Yes, during the past year
# 3                          Yes, during the past year
# 4                                                 No
# 5                          Yes, during the past year
# 6                      Yes, but not in the past year
# 7                          Yes, during the past year
# 8                          Yes, during the past year
# 9                                                 No
#
#   Has someone been concerned about your drinking or suggested cutting down?  \
# 0                          Yes, during the past year
# 1                      Yes, but not in the past year
# 2                          Yes, during the past year
# 3                          Yes, during the past year
# 4                                                 No
# 5                      Yes, but not in the past year
# 6                                                 No
# 7                      Yes, but not in the past year
# 8                      Yes, but not in the past year
# 9                      Yes, but not in the past year
#
#    Total Score              Level
# 0           21  Alcohol Dependent
# 1           11          Hazardous
# 2           19  Alcohol Dependent
# 3           19  Alcohol Dependent
# 4           16  Alcohol Dependent
# 5           18  Alcohol Dependent
# 6           17  Alcohol Dependent
# 7           21  Alcohol Dependent
# 8           17  Alcohol Dependent
# 9           12          Hazardous

# %%
df.drop('Participant ID', axis=1, inplace=True)
df.head(10)
# Out:
#   How often do you have a drink containing alcohol?  \
# 0                                             Never
# 1                                             Never
# 2                            4 or more times a week
# 3                                 2-4 times a month
# 4                                             Never
# 5                                             Never
# 6                                   Monthly or less
# 7                                 2-4 times a month
# 8                                 2-4 times a month
# 9                                   Monthly or less
#
#   How many standard drinks do you have on a typical drinking day?  \
# 0                                             5 or 6
# 1                                             5 or 6
# 2                                         10 or more
# 3                                             5 or 6
# 4                                             5 or 6
# 5                                         10 or more
# 6                                             5 or 6
# 7                                             7 to 9
# 8                                             3 or 4
# 9                                             3 or 4
#
#   How often do you have six or more drinks on one occasion?  \
# 0                              Daily or almost daily
# 1                                              Never
# 2                                  Less than monthly
# 3                                  Less than monthly
# 4                                              Never
# 5                                              Never
# 6                                            Monthly
# 7                                             Weekly
# 8                                  Less than monthly
# 9                              Daily or almost daily
#
#   How often do you find it hard to stop drinking once started?  \
# 0                                             Weekly
# 1                                            Monthly
# 2                              Daily or almost daily
# 3                              Daily or almost daily
# 4                              Daily or almost daily
# 5                              Daily or almost daily
# 6                              Daily or almost daily
# 7                              Daily or almost daily
# 8                                             Weekly
# 9                                              Never
#
#   How often do you fail to do what is expected due to drinking?  \
# 0                                  Less than monthly
# 1                                              Never
# 2                                  Less than monthly
# 3                                             Weekly
# 4                                             Weekly
# 5                                              Never
# 6                              Daily or almost daily
# 7                                  Less than monthly
# 8                                             Weekly
# 9                              Daily or almost daily
#
#   How often do you need a drink in the morning after heavy drinking?  \
# 0                              Daily or almost daily
# 1                                  Less than monthly
# 2                                             Weekly
# 3                                  Less than monthly
# 4                                  Less than monthly
# 5                                            Monthly
# 6                                             Weekly
# 7                                             Weekly
# 8                                             Weekly
# 9                                            Monthly
#
#   How often do you feel guilt or remorse after drinking?  \
# 0                              Daily or almost daily
# 1                              Daily or almost daily
# 2                                            Monthly
# 3                                            Monthly
# 4                                             Weekly
# 5                              Daily or almost daily
# 6                                  Less than monthly
# 7                                            Monthly
# 8                              Daily or almost daily
# 9                                              Never
#
#   How often do you forget what happened because of drinking?  \
# 0                                             Weekly
# 1                                            Monthly
# 2                                              Never
# 3                              Daily or almost daily
# 4                                             Weekly
# 5                              Daily or almost daily
# 6                                              Never
# 7                                             Weekly
# 8                                              Never
# 9                                              Never
#
#   Have you or someone else been injured due to your drinking?  \
# 0                                                 No
# 1                                                 No
# 2                          Yes, during the past year
# 3                          Yes, during the past year
# 4                                                 No
# 5                          Yes, during the past year
# 6                      Yes, but not in the past year
# 7                          Yes, during the past year
# 8                          Yes, during the past year
# 9                                                 No
#
#   Has someone been concerned about your drinking or suggested cutting down?  \
# 0                          Yes, during the past year
# 1                      Yes, but not in the past year
# 2                          Yes, during the past year
# 3                          Yes, during the past year
# 4                                                 No
# 5                      Yes, but not in the past year
# 6                                                 No
# 7                      Yes, but not in the past year
# 8                      Yes, but not in the past year
# 9                      Yes, but not in the past year
#
#    Total Score              Level
# 0           21  Alcohol Dependent
# 1           11          Hazardous
# 2           19  Alcohol Dependent
# 3           19  Alcohol Dependent
# 4           16  Alcohol Dependent
# 5           18  Alcohol Dependent
# 6           17  Alcohol Dependent
# 7           21  Alcohol Dependent
# 8           17  Alcohol Dependent
# 9           12          Hazardous

# %%
df.rename(columns={'How often do you have a drink containing alcohol?': 'Q1', 'How many standard drinks do you have on a typical drinking day?': 'Q2' , 'How often do you have six or more drinks on one occasion?':'Q3'
                  ,'How often do you find it hard to stop drinking once started?':'Q4','How often do you fail to do what is expected due to drinking?':'Q5',
                  'How often do you need a drink in the morning after heavy drinking?':'Q6','How often do you feel guilt or remorse after drinking?':'Q7',
                  'How often do you forget what happened because of drinking?':'Q8','Have you or someone else been injured due to your drinking?':'Q9','Has someone been concerned about your drinking or suggested cutting down?':'Q10'}, inplace=True)

# %%
df.head(20)
# Out:
#                         Q1          Q2                     Q3  \
# 0                    Never      5 or 6  Daily or almost daily
# 1                    Never      5 or 6                  Never
# 2   4 or more times a week  10 or more      Less than monthly
# 3        2-4 times a month      5 or 6      Less than monthly
# 4                    Never      5 or 6                  Never
# 5                    Never  10 or more                  Never
# 6          Monthly or less      5 or 6                Monthly
# 7        2-4 times a month      7 to 9                 Weekly
# 8        2-4 times a month      3 or 4      Less than monthly
# 9          Monthly or less      3 or 4  Daily or almost daily
# 10         Monthly or less  10 or more      Less than monthly
# 11       2-4 times a month      1 or 2                 Weekly
# 12         Monthly or less  10 or more                 Weekly
# 13        2-3 times a week  10 or more                Monthly
# 14        2-3 times a week  10 or more                 Weekly
# 15        2-3 times a week      3 or 4  Daily or almost daily
# 16  4 or more times a week      7 to 9                 Weekly
# 17        2-3 times a week      3 or 4                 Weekly
# 18       2-4 times a month      5 or 6  Daily or almost daily
# 19                   Never      5 or 6                  Never
#
#                        Q4                     Q5                     Q6  \
# 0                  Weekly      Less than monthly  Daily or almost daily
# 1                 Monthly                  Never      Less than monthly
# 2   Daily or almost daily      Less than monthly                 Weekly
# 3   Daily or almost daily                 Weekly      Less than monthly
# 4   Daily or almost daily                 Weekly      Less than monthly
# 5   Daily or almost daily                  Never                Monthly
# 6   Daily or almost daily  Daily or almost daily                 Weekly
# 7   Daily or almost daily      Less than monthly                 Weekly
# 8                  Weekly                 Weekly                 Weekly
# 9                   Never  Daily or almost daily                Monthly
# 10  Daily or almost daily      Less than monthly                 Weekly
# 11                 Weekly                  Never                  Never
# 12      Less than monthly  Daily or almost daily                Monthly
# 13                 Weekly      Less than monthly      Less than monthly
# 14                  Never                 Weekly                  Never
# 15                Monthly                 Weekly                 Weekly
# 16                 Weekly                Monthly      Less than monthly
# 17                Monthly                  Never  Daily or almost daily
# 18                  Never                 Weekly                  Never
# 19                Monthly                 Weekly      Less than monthly
#
#                        Q7                     Q8  \
# 0   Daily or almost daily                 Weekly
# 1   Daily or almost daily                Monthly
# 2                 Monthly                  Never
# 3                 Monthly  Daily or almost daily
# 4                  Weekly                 Weekly
# 5   Daily or almost daily  Daily or almost daily
# 6       Less than monthly                  Never
# 7                 Monthly                 Weekly
# 8   Daily or almost daily                  Never
# 9                   Never                  Never
# 10                 Weekly                 Weekly
# 11                Monthly  Daily or almost daily
# 12      Less than monthly      Less than monthly
# 13                  Never                  Never
# 14                Monthly                 Weekly
# 15                Monthly                  Never
# 16                 Weekly  Daily or almost daily
# 17      Less than monthly                Monthly
# 18      Less than monthly                  Never
# 19                 Weekly  Daily or almost daily
#
#                                Q9                            Q10  Total Score  \
# 0                              No      Yes, during the past year           21
# 1                              No  Yes, but not in the past year           11
# 2       Yes, during the past year      Yes, during the past year           19
# 3       Yes, during the past year      Yes, during the past year           19
# 4                              No                             No           16
# 5       Yes, during the past year  Yes, but not in the past year           18
# 6   Yes, but not in the past year                             No           17
# 7       Yes, during the past year  Yes, but not in the past year           21
# 8       Yes, during the past year  Yes, but not in the past year           17
# 9                              No  Yes, but not in the past year           12
# 10                             No                             No           20
# 11                             No      Yes, during the past year           14
# 12  Yes, but not in the past year                             No           17
# 13  Yes, but not in the past year                             No           14
# 14  Yes, but not in the past year                             No           18
# 15  Yes, but not in the past year      Yes, during the past year           18
# 16                             No                             No           23
# 17      Yes, during the past year      Yes, during the past year           16
# 18      Yes, during the past year                             No           12
# 19      Yes, during the past year                             No           15
#
#                 Level
# 0   Alcohol Dependent
# 1           Hazardous
# 2   Alcohol Dependent
# 3   Alcohol Dependent
# 4   Alcohol Dependent
# 5   Alcohol Dependent
# 6   Alcohol Dependent
# 7   Alcohol Dependent
# 8   Alcohol Dependent
# 9           Hazardous
# 10  Alcohol Dependent
# 11          Hazardous
# 12  Alcohol Dependent
# 13          Hazardous
# 14  Alcohol Dependent
# 15  Alcohol Dependent
# 16  Alcohol Dependent
# 17  Alcohol Dependent
# 18          Hazardous
# 19  Alcohol Dependent

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Q1']=le.fit_transform(df['Q1'])
df['Q2']=le.fit_transform(df['Q2'])
df['Q3']=le.fit_transform(df['Q3'])
df['Q4']=le.fit_transform(df['Q4'])
df['Q5']=le.fit_transform(df['Q5'])
df['Q6']=le.fit_transform(df['Q6'])
df['Q7']=le.fit_transform(df['Q7'])
df['Q8']=le.fit_transform(df['Q8'])
df['Q9']=le.fit_transform(df['Q9'])
df['Q10']=le.fit_transform(df['Q10'])

# %%
#df['Level']=le.fit_transform(df['Level'])
df.head()
# Out:
#    Q1  Q2  Q3  Q4  Q5  Q6  Q7  Q8  Q9  Q10  Total Score              Level
# 0   4   3   0   4   1   0   0   4   0    2           21  Alcohol Dependent
# 1   4   3   3   2   3   1   0   2   0    1           11          Hazardous
# 2   2   1   1   0   1   4   2   3   2    2           19  Alcohol Dependent
# 3   1   3   1   0   4   1   2   0   2    2           19  Alcohol Dependent
# 4   4   3   3   0   4   1   4   4   0    0           16  Alcohol Dependent

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd



# Assuming 'numeric_columns' contains the names of numerical columns in your dataset
numeric_columns = ['Q1','Q2','Q3','Q4','Q5','Q6','Q7','Q8','Q9','Q10']

# Calculate skewness for each numerical column
skewness_values = df[numeric_columns].skew()

# Display skewness values
print(skewness_values)
# Out:
# Q1    -0.012997
# Q2     0.005904
# Q3     0.011891
# Q4     0.013784
# Q5    -0.004416
# Q6    -0.004467
# Q7     0.043430
# Q8     0.001333
# Q9     0.003678
# Q10   -0.031686
# dtype: float64

# %%
import numpy as np

# Assuming 'numeric_columns' contains the names of numerical columns in your dataset
numeric_columns = ['Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6', 'Q7', 'Q8', 'Q9', 'Q10']

# Apply a transformation to reduce skewness (e.g., logarithmic transformation)
transformed_data = np.log1p(df[numeric_columns])

# Calculate skewness for each transformed numerical column
skewness_values_after_transformation = transformed_data.skew()

# Display skewness values after transformation
print(skewness_values_after_transformation)
# Out:
# Q1    -0.595304
# Q2    -0.591946
# Q3    -0.563084
# Q4    -0.571853
# Q5    -0.592501
# Q6    -0.594077
# Q7    -0.557388
# Q8    -0.571629
# Q9    -0.302821
# Q10   -0.354847
# dtype: float64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'numeric_columns' contains the names of numerical columns in your dataset
numeric_columns = ['Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6', 'Q7', 'Q8', 'Q9', 'Q10']

# Original data
original_data = df[numeric_columns]

# Transformed data (logarithmic transformation)
transformed_data = np.log1p(original_data)

# Set up subplots
fig, axes = plt.subplots(nrows=2, ncols=len(numeric_columns), figsize=(15, 6))

# Plot histograms for original data
for i, col in enumerate(numeric_columns):
    sns.histplot(original_data[col], kde=True, ax=axes[0, i])
    axes[0, i].set_title(f'Original {col}')

# Plot histograms for transformed data
for i, col in enumerate(numeric_columns):
    sns.histplot(transformed_data[col], kde=True, ax=axes[1, i])
    axes[1, i].set_title(f'Transformed {col}')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
from sklearn.model_selection import train_test_split
y=df['Level']
X_train, X_test, y_train, y_test = train_test_split(transformed_data, y, test_size=0.2, random_state=42)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

# SVM model training
svm_model = SVC(kernel='linear')  # You can try different kernels ('linear', 'rbf', 'poly', etc.)
svm_model.fit(X_train, y_train)


predictions = svm_model.predict(X_test)
accuracy = accuracy_score(y_test, predictions)
report = classification_report(y_test, predictions)

print(f"Accuracy: {accuracy}")
print(f"Classification Report:\n{report}")
# Out:
# Accuracy: 0.655
# Classification Report:
#                    precision    recall  f1-score   support
#
# Alcohol Dependent       0.66      1.00      0.79       655
#         Hazardous       0.00      0.00      0.00       328
#          Low risk       0.00      0.00      0.00        17
#
#          accuracy                           0.66      1000
#         macro avg       0.22      0.33      0.26      1000
#      weighted avg       0.43      0.66      0.52      1000
# C:\Users\Navyashri\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Navyashri\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Navyashri\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
svm = SVC(C=100, gamma=0.1)

svm.fit(X_train, y_train)

# Make predictions on the test/validation set
predictions = svm.predict(X_test)

# Evaluate the model's performance
accuracy = accuracy_score(y_test, predictions)
print(f"Accuracy on Test/Validation Set: {accuracy:.4f}")
# Out:
# Accuracy on Test/Validation Set: 0.7890

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import make_scorer, accuracy_score

# Define the SVM model
svm = SVC()

# Define the hyperparameters and their values for tuning
param_grid = {
    'C': [0.1, 1, 10, 100],  
    'gamma': [0.1, 1, 10]    
}

# scoring metric
scorer = make_scorer(accuracy_score)

# GridSearchCV
grid_search = GridSearchCV(estimator=svm, param_grid=param_grid, scoring=scorer, cv=3)
grid_result = grid_search.fit(X_train, y_train)

# Get the best parameters and best score
best_params = grid_result.best_params_
best_score = grid_result.best_score_

print("Best Parameters:", best_params)
print("Best Accuracy:", best_score)
# Out:
# Best Parameters: {'C': 10, 'gamma': 0.1}
# Best Accuracy: 0.7779988475379715

# %%
from sklearn.tree import DecisionTreeClassifier

dt_model = DecisionTreeClassifier(random_state=42)  # You can set different hyperparameters here
dt_model.fit(X_train, y_train)

# Model evaluation
predictions = dt_model.predict(X_test)
accuracy = accuracy_score(y_test, predictions)
report = classification_report(y_test, predictions)

print(f"Accuracy: {accuracy}")
print(f"Classification Report:\n{report}")
# Out:
# Accuracy: 0.741
# Classification Report:
#                    precision    recall  f1-score   support
#
# Alcohol Dependent       0.82      0.80      0.81       655
#         Hazardous       0.60      0.64      0.62       328
#          Low risk       0.40      0.35      0.38        17
#
#          accuracy                           0.74      1000
#         macro avg       0.61      0.60      0.60      1000
#      weighted avg       0.74      0.74      0.74      1000

# %%
from sklearn.ensemble import RandomForestClassifier

# Instantiate the Random Forest classifier
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)  # You can adjust hyperparameters here

# Train the model
rf_model.fit(X_train, y_train)

# Make predictions
rf_predictions = rf_model.predict(X_test)

# Evaluate the model
rf_accuracy = accuracy_score(y_test, rf_predictions)
rf_report = classification_report(y_test, rf_predictions)

print(f"Random Forest Accuracy: {rf_accuracy}")
print(f"Random Forest Classification Report:\n{rf_report}")
# Out:
# Random Forest Accuracy: 0.845
# Random Forest Classification Report:
#                    precision    recall  f1-score   support
#
# Alcohol Dependent       0.86      0.95      0.90       655
#         Hazardous       0.82      0.68      0.74       328
#          Low risk       0.00      0.00      0.00        17
#
#          accuracy                           0.84      1000
#         macro avg       0.56      0.54      0.55      1000
#      weighted avg       0.83      0.84      0.83      1000
# C:\Users\Navyashri\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Navyashri\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Navyashri\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
new_data=[[3,0,1,0,1,2,4,0,1,4]]
predicted_class = rf_model.predict(new_data)

print("Predicted Class:", predicted_class)
# Out:
# Predicted Class: ['Hazardous']
# C:\Users\Navyashri\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
new_data=[[0,0,0,0,1,2,0,0,1,0]]
predicted_class = rf_model.predict(new_data)

print("Predicted Class:", predicted_class)
# Out:
# Predicted Class: ['Alcohol Dependent']
# C:\Users\Navyashri\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.metrics import accuracy_score, classification_report

# Initialize Random Forest as the base estimator
base_estimator = RandomForestClassifier(n_estimators=100, random_state=42)

# Initialize AdaBoost classifier with Random Forest as base estimator
adaboost_classifier = AdaBoostClassifier(base_estimator=base_estimator, n_estimators=50, random_state=42)

# Train the AdaBoost classifier
adaboost_classifier.fit(X_train, y_train)

# Make predictions
adaboost_predictions = adaboost_classifier.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, adaboost_predictions)
print(f"AdaBoost with Random Forest Accuracy: {accuracy}")

# Generate classification report
report = classification_report(y_test, adaboost_predictions)
print(f"Classification Report:\n{report}")
# Out:
# AdaBoost with Random Forest Accuracy: 0.851
# Classification Report:
#                    precision    recall  f1-score   support
#
# Alcohol Dependent       0.86      0.95      0.90       655
#         Hazardous       0.83      0.69      0.75       328
#          Low risk       0.00      0.00      0.00        17
#
#          accuracy                           0.85      1000
#         macro avg       0.56      0.55      0.55      1000
#      weighted avg       0.83      0.85      0.84      1000
# C:\Users\Navyashri\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Navyashri\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Navyashri\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
new_data=[[0,0,0,0,1,2,0,0,1,0]]
predicted_class = adaboost_classifier.predict(new_data)

print("Predicted Class:", predicted_class)
# Out:
# Predicted Class: ['Alcohol Dependent']
# C:\Users\Navyashri\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but AdaBoostClassifier was fitted with feature names
#   warnings.warn(

# %%
new_data=[[4,3,3,4,4,1,4,2,4,1]]
predicted_class = adaboost_classifier.predict(new_data)

print("Predicted Class:", predicted_class)
# Out:
# Predicted Class: ['Alcohol Dependent']
# C:\Users\Navyashri\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but AdaBoostClassifier was fitted with feature names
#   warnings.warn(
